# %% [markdown]
# # 03 - Failure Analysis
# Analyze worst-case predictions and failure modes.

# %%
import numpy as np
# Load all_preds and all_targets from evaluate.py
# Sort by FDE and inspect top-k failures
