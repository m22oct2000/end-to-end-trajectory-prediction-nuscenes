# %% [markdown]
# # 02 - Visualize Predictions
# Load a checkpoint and visualize predicted vs ground truth trajectories.

# %%
import sys; sys.path.append('..')
from utils.visualization import visualize_trajectory
import numpy as np
# Load predictions from evaluate.py output and call visualize_trajectory()
